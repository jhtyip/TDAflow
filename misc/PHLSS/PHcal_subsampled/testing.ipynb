# %%
import numpy as np

# %%
num_array = np.load("numOfGals_fiducial.txt.npy")

# %%
print(num_array)
# Out:
# [355796 356695 356154 ... 356032 355996 356135]

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(num_array, bins=100)
plt.show()

# %%
np.amin(num_array)*99.5/100
# Out:
# 352526.51
